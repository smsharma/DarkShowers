# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pb = 1;
ab = 10**-6*pb;

# %%
eventsSigObj = pd.read_csv('Zh.obj', sep=',', skipinitialspace=True,index_col=('evt','type','n')) 
eventsSigEvt = pd.read_csv('Zh.evt', sep=',', skipinitialspace=True) 
eventsSigMeta = pd.read_csv('Zh.meta', sep=',', skipinitialspace=True) 

eventsBkgObj = pd.read_csv('Zjets.obj', sep=',', skipinitialspace=True,index_col=('evt','type','n')) 
eventsBkgEvt = pd.read_csv('Zjets.evt', sep=',', skipinitialspace=True) 
eventsBkgMeta = pd.read_csv('Zjets.meta', sep=',', skipinitialspace=True)

# %%
sigEff = 1.*len(eventsSigEvt[eventsSigEvt['met'] > metCut])/len(eventsSigEvt)
bkgEff = 1.*len(eventsBkgEvt[eventsBkgEvt['met'] > metCut])/len(eventsBkgEvt)
print "Signal efficiency:",  sigEff
print "Background efficiency:",  bkgEff
print
Nsigevt = eventsSigMeta['cxn'][0]*pb*(1/ab)*sigEff
Nbkgevt = eventsBkgMeta['cxn'][0]*pb*(1/ab)*bkgEff
print "Signal events expected in 1 /ab:", Nsigevt
print "Background events expected in 1 /ab:", Nbkgevt
# Out:
# Signal efficiency: 0.147117296223
# Background efficiency: 0.00579374275782
#
# Signal events expected in 1 /ab: 276.000874751
# Background events expected in 1 /ab: 5884.06720742

# %%
print eventsSigEvt.columns.values
# Out:
# ['evt' 'tag' 'met' 'dphi_higgs_met' 'dphi_jet1_met' 'dphi_jet2_met'
#  'dphi_jet1_jet2' 'm_mu_mu' 'm_jj' 'm_t' 'm_c' 'num_jets' 'num_reco_muons'
#  'num_gen_muons' 'num_bs' 'num_charged' 'num_diag' 'num_dark' 'higgs_pt']

# %%
Nsigevt*(eventsSigEvt['num_gen_muons'].fillna(-999).values),
# Out:
# (array([    552.0017495 ,     552.0017495 ,     552.0017495 , ...,
#         -275724.87387674, -275724.87387674, -275724.87387674]),)

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = np.linspace(0, 9, 10)

lw=2;
# plt.hist(events[cut][' MT'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_T$',linewidth=lw)
# plt.hist(events[cut][' Mjj'].fillna(-999).values, bins, alpha=1.0,histtype='step',label=r'$M_j$',linewidth=lw)
# plt.hist(events[cut][' Mscaled'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_{j,sc}$',linewidth=lw)
fig, axs = plt.subplots(1,2)

axs[0].hist(1*(eventsSigEvt['num_gen_muons'].fillna(-999).values), bins, alpha=1.0, normed=1, histtype='step',label=r'Gen Muons',linewidth=lw, log=True, weights = )
axs[0].hist(1*(eventsSigEvt['num_reco_muons'].fillna(-999).values), bins, alpha=1.0, normed=1, histtype='step',label=r'Reco Muons',linewidth=lw, log=True)

axs[1].hist(1*(eventsBkgEvt['num_gen_muons'].fillna(-999).values), bins, alpha=1.0, normed=Nbkgevt, histtype='step',label=r'Gen Muons',linewidth=lw, log=True)
axs[1].hist(1*(eventsBkgEvt['num_reco_muons'].fillna(-999).values), bins, alpha=1.0, normed=Nbkgevt, histtype='step',label=r'Reco Muons',linewidth=lw, log=True)

axs[1].legend(loc='upper right')

plt.show()
# Out:
#   File "<ipython-input-7-7b0a9235fb5f>", line 12
#     axs[0].hist(1*(eventsSigEvt['num_gen_muons'].fillna(-999).values), bins, alpha=1.0, normed=1, histtype='step',label=r'Gen Muons',linewidth=lw, log=True, weights = )
#                                                                                                                                                                        ^
# SyntaxError: invalid syntax

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = np.linspace(0, 200, 201)

lw=2;
# plt.hist(events[cut][' MT'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_T$',linewidth=lw)
# plt.hist(events[cut][' Mjj'].fillna(-999).values, bins, alpha=1.0,histtype='step',label=r'$M_j$',linewidth=lw)
# plt.hist(events[cut][' Mscaled'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_{j,sc}$',linewidth=lw)
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['num_charged'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'Gen Muons',linewidth=lw, log=True)
axs[1].hist(eventsBkgEvt['num_bs'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'Reco Muons',linewidth=lw, log=True)
axs[1].legend(loc='upper right')

# plt.hist(events[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt1',linewidth=lw)
# plt.hist(events[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt2',linewidth=lw)
# plt.hist(events[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)
# plt.hist(events[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)

plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 70, 50)

cut = (events[' JetPt'] > 0) & (events[' dphi'] < 999) & (events[' met'] > 0)
lw=2;
# plt.hist(events[cut][' MT'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_T$',linewidth=lw)
# plt.hist(events[cut][' Mjj'].fillna(-999).values, bins, alpha=1.0,histtype='step',label=r'$M_j$',linewidth=lw)
# plt.hist(events[cut][' Mscaled'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_{j,sc}$',linewidth=lw)
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSig[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu1',linewidth=lw, log=0)
axs[0].hist(eventsSig[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu2',linewidth=lw, log=0)
axs[0].hist(eventsSig[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu3',linewidth=lw, log=0)
axs[0].hist(eventsSig[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu4',linewidth=lw, log=0)

axs[1].hist(eventsBkg[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu1',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu2',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu3',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu4',linewidth=lw, log=0)

axs[1].legend(loc='upper right')

# plt.hist(events[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt1',linewidth=lw)
# plt.hist(events[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt2',linewidth=lw)
# plt.hist(events[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)
# plt.hist(events[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)


plt.savefig('hist.pdf')
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 150, 20)

cut = (events[' JetPt'] > 0) & (events[' dphi'] < 999) & (events[' met'] > 0)
lw=2;
# plt.hist(events[cut][' MT'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_T$',linewidth=lw)
# plt.hist(events[cut][' Mjj'].fillna(-999).values, bins, alpha=1.0,histtype='step',label=r'$M_j$',linewidth=lw)
# plt.hist(events[cut][' Mscaled'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_{j,sc}$',linewidth=lw)
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSig[cut][' MMu2'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'M($\mu\mu$)',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' MMu2'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'M($\mu\mu$)',linewidth=lw, log=0)

axs[1].legend(loc='upper right')

# plt.hist(events[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt1',linewidth=lw)
# plt.hist(events[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt2',linewidth=lw)
# plt.hist(events[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)
# plt.hist(events[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)


plt.savefig('hist.pdf')
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 70, 50)

cut = (events[' JetPt'] > 0) & (events[' dphi'] < 999) & (events[' met'] > 0)
lw=2;
# plt.hist(events[cut][' MT'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_T$',linewidth=lw)
# plt.hist(events[cut][' Mjj'].fillna(-999).values, bins, alpha=1.0,histtype='step',label=r'$M_j$',linewidth=lw)
# plt.hist(events[cut][' Mscaled'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_{j,sc}$',linewidth=lw)
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSig[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu1',linewidth=lw, log=0)
axs[0].hist(eventsSig[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu2',linewidth=lw, log=0)
axs[0].hist(eventsSig[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu3',linewidth=lw, log=0)
axs[0].hist(eventsSig[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu4',linewidth=lw, log=0)

axs[1].hist(eventsBkg[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu1',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu2',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu3',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'PtMu4',linewidth=lw, log=0)

axs[1].legend(loc='upper right')

# plt.hist(events[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt1',linewidth=lw)
# plt.hist(events[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt2',linewidth=lw)
# plt.hist(events[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)
# plt.hist(events[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)


plt.savefig('hist.pdf')
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 250, 25)

cutSig = (eventsSig[' PtMu1'] > 20) & (eventsSig[' dphi'] < 999) & (eventsSig[' met'] > 0)
cutBkg = (eventsBkg[' PtMu1'] > 20) & (eventsBkg[' dphi'] < 999) & (eventsBkg[' met'] > 0)

lw=2;
# plt.hist(events[cut][' MT'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_T$',linewidth=lw)
# plt.hist(events[cut][' Mjj'].fillna(-999).values, bins, alpha=1.0,histtype='step',label=r'$M_j$',linewidth=lw)
# plt.hist(events[cut][' Mscaled'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'$M_{j,sc}$',linewidth=lw)
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSig[cutSig][' MT'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_T$',linewidth=lw, log=0)
axs[0].hist(eventsSig[cutSig][' Mjj'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
axs[0].hist(eventsSig[cutSig][' met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'MET',linewidth=lw, log=0)

axs[1].hist(eventsBkg[cutBkg][' MT'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_T$',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cutBkg][' Mjj'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
axs[1].hist(eventsBkg[cutBkg][' met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'MET',linewidth=lw, log=0)

axs[1].legend(loc='upper right')

# plt.hist(events[cut][' PtMu1'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt1',linewidth=lw)
# plt.hist(events[cut][' PtMu2'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt2',linewidth=lw)
# plt.hist(events[cut][' PtMu3'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)
# plt.hist(events[cut][' PtMu4'].fillna(-999).values, bins, alpha=1.0, histtype='step',label=r'Pt3',linewidth=lw)


plt.savefig('hist.pdf')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 14, 14 
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['font.size'] = 16

 
fig, axs = plt.subplots(4,4)

n_events=16;
i_events=0;
for i in range(int(np.sqrt(n_events))):
    for j in range(int(np.sqrt(n_events))):

        vislist=eventsSigObj.xs((i_events,'vis'),level=('evt','type'))
        invislist=eventsSigObj.xs((i_events,'invis'),level=('evt','type'))
        muonlist=eventsSigObj.xs((i_events,'muon'),level=('evt','type'))
        jetlist=eventsSigObj.xs((i_events,'jet'),level=('evt','type'))

        axs[i][j].scatter(vislist['eta'], vislist['phi'], s=10*vislist['pt'], c=[1,0,0],alpha=0.5)
        axs[i][j].scatter(invislist['eta'], invislist['phi'], s=10*invislist['pt'], c=[0,0,0], alpha=0.5)
        axs[i][j].scatter(muonlist['eta'], muonlist['phi'], s=10*muonlist['pt'], c=[0,0,1],alpha=0.5, marker='$\mu$' )
        axs[i][j].scatter(jetlist['eta'], jetlist['phi'], s=10*jetlist['pt'], c=[0,1,0],alpha=0.5, marker='$j$' )

        axs[i][j].set_xlabel('$\eta$')
        axs[i][j].set_ylabel('$\phi$')

        axs[i][j].set_xlim(-5,  5)
        axs[i][j].set_ylim(0, 2*np.pi)
 
        
        i_events+=1;
        
plt.tight_layout()
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 250, 50)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['m_jj'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
axs[0].hist(eventsSigEvt['m_t'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)

axs[1].hist(eventsBkgEvt['m_jj'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
axs[1].hist(eventsBkgEvt['m_t'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 10, 11)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['num_bs'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{B}$',linewidth=lw, log=1)

axs[1].hist(eventsBkgEvt['num_bs'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{B}$',linewidth=lw, log=1)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 10, 11)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['num_gen_muons'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{\mu, gen}$',linewidth=lw, log=0)
axs[0].hist(eventsSigEvt['num_reco_muons'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{\mu, reco}$',linewidth=lw, log=0)

axs[1].hist(eventsBkgEvt['num_gen_muons'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{\mu, gen}$',linewidth=lw, log=0)
axs[1].hist(eventsBkgEvt['num_reco_muons'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{\mu, reco}$',linewidth=lw, log=0)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 100, 25)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigObj.xs(('charged',0),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T1$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('charged',1),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T2$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('charged',2),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T3$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('charged',3),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T4$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('charged',4),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T5$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('charged',5),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T6$',linewidth=lw, log=0)

# axs[1].hist(eventsBkgObj.xs(('jet',0),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
# axs[1].hist(eventsBkgObj.xs(('jet',1),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)

axs[0].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 100, 50)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigObj.xs(('muon',0),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('muon',1),level=('type','n'))['pt'], bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('muon',2),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
axs[0].hist(eventsSigObj.xs(('muon',3),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)

axs[1].hist(eventsBkgObj.xs(('muon',0),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
axs[1].hist(eventsBkgObj.xs(('muon',1),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
axs[1].hist(eventsBkgObj.xs(('muon',2),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)
axs[1].hist(eventsBkgObj.xs(('muon',3),level=('type','n'))['pt'].values, bins, alpha=1.0, normed=False, histtype='step',label=r'$p_T$',linewidth=lw, log=0)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 150, 50)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['m_mu_mu'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{B}$',linewidth=lw, log=1)

axs[1].hist(eventsBkgEvt['m_mu_mu'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$N_{B}$',linewidth=lw, log=1)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 4, 50)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['dphi_higgs_met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
axs[0].hist(eventsSigEvt['dphi_jet1_met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)
axs[0].hist(eventsSigEvt['dphi_jet2_met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)

axs[1].hist(eventsBkgEvt['dphi_higgs_met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
axs[1].hist(eventsBkgEvt['dphi_jet1_met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)
axs[1].hist(eventsBkgEvt['dphi_jet2_met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 200, 50)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(eventsSigEvt['met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=0)
#axs[0].hist(eventsBkgEvt['met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)

axs[1].hist(eventsBkgEvt['met'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$MET$',linewidth=lw, log=0)
# axs[1].hist(eventsBkgEvt['m_t'].fillna(-999).values, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{T}$',linewidth=lw, log=0)

axs[1].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()

# %%
v1=[];
v2=[];
for i,it in enumerate(eventsSigEvt['dphi_jet1_met'].fillna(999).values):
    v1.append(np.min([it,eventsSigEvt['dphi_jet2_met'].fillna(999).values[i]]))
for i,it in enumerate(eventsBkgEvt['dphi_jet1_met'].fillna(999).values):
    v2.append(np.min([it,eventsBkgEvt['dphi_jet2_met'].fillna(999).values[i]]))

# %%
import random
import numpy
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = 16, 6.798 
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y'])

bins = numpy.linspace(0, 4, 50)
lw=2;
fig, axs = plt.subplots(1,2)

axs[0].hist(ef0*v1, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=1)
axs[0].hist(v2, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=1)

axs[0].legend(loc='upper right')


plt.savefig('hist.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-f3e09e895541> in <module>()
#      10 fig, axs = plt.subplots(1,2)
#      11
# ---> 12 axs[0].hist(ef0*v1, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=1)
#      13 axs[0].hist(v2, bins, alpha=1.0, normed=False, histtype='step',label=r'$M_{jj}$',linewidth=lw, log=1)
#      14
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5694
#    5695         # basic input validation
# -> 5696         flat = np.ravel(x)
#    5697
#    5698         input_empty = len(flat) == 0
#
# /usr/local/lib/python2.7/site-packages/numpy-1.10.0.dev_cfa095a-py2.7-macosx-10.9-x86_64.egg/numpy/core/fromnumeric.pyc in ravel(a, order)
# ...
