# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
events = pd.read_csv('higgz1_4.evt', sep=',')

# %%
events.head()
# Out:
#   event   jet_narrow   jet       met   met_phi      dphi   eta_max      deta  \
# 0     1            4     2  31.51120  2.505660  0.913245   0.99332  0.460908
# 1     2            6     3  13.00840  3.046640  0.275890   2.30531  0.543142
# 2     3            8     3  42.39410  0.712365  0.336854   1.43116  1.824290
# 3     4            6     3   9.21266  4.589020  0.954311   1.41392  2.795380
# 4     5            4     2  17.37250  1.805480  0.817124   1.80993  0.827981
#
#        drap       HT       MJ       Mjj        MT      Mcol       Mmc
# 0  0.481135  1914.17  307.488  205.8860  234.6450  3954.310  1096.300
# 1  0.556053  4830.09  232.064   97.6008   99.0324   808.548   676.142
# 2  1.647410  3870.25  884.315  524.8190  527.2890  3011.050  1779.530
# 3  2.609320  3905.96  594.591  260.2010  266.0270  1989.750  1939.220
# 4  0.727016  2521.73  631.652  265.6910  274.5690  8433.400  1178.110

# %%
events.columns.values
# Out:
# array(['event', ' jet_narrow', ' jet', ' met', ' met_phi', ' dphi',
#        ' eta_max', ' deta', ' drap', 'HT', ' MJ', ' Mjj', ' MT', ' Mcol',
#        ' Mmc'], dtype=object)

# %%
import random
import numpy
from matplotlib import pyplot

x = [random.gauss(3,1) for _ in range(400)]
y = [random.gauss(4,2) for _ in range(400)]

bins = numpy.linspace(0, 200, 20)

pyplot.hist(events[' MT'].fillna(-999).values, bins, alpha=0.5, label='MT')
pyplot.hist(events[' Mjj'].fillna(-999).values, bins, alpha=0.5, label='Mj')
pyplot.legend(loc='upper right')
pyplot.show()
