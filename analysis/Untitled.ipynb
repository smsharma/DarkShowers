# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
for mass in [10,20,50,100,200,500,1000]:
    tab = pd.read_csv("../gen/monojet_"+str(mass)+"_rinv0.4.evt")
    print mass ,np.mean(tab[tab["MEt"] > 500]['n_meson']),np.mean(tab[tab["MEt"] > 500]['n_glu'])
# Out:
# 10 14.2341207349 0.0
# 20 10.2865994636 0.0
# 50 6.58260869565 0.000226843100189
# 100 4.73526187576 0.00200974421437
# 200 3.3385799473 0.0105394536125
# 500 2.03211030398 0.29547031879
# 1000 1.50685405269 0.672011570144

# %%
tab
# Out:
#          evt        MEt        pt1      eta1        pt2        eta2  \
# 0          0   469.1690   919.0660  0.408398   602.1570    2.135930
# 1          1    19.3296    30.9047 -0.585218    -1.0000  999.000000
# 2          2   476.7510  1088.3500  0.072542   717.7390    0.759336
# 3          3   274.2120   260.4010  0.156296    -1.0000  999.000000
# 4          4  1095.3200   962.9190 -0.115612   909.3650    1.351570
# 5          5   871.5510  1448.8900 -0.205076   623.0600   -0.487639
# 6          6  1154.0700  2406.1900  1.035420  1541.0100   -0.856578
# 7          7   234.4740   711.4170 -0.107045   624.7560    1.530940
# 8          8   628.4720   584.2320 -1.209780    60.7603   -1.715630
# 9          9   129.3930  1086.2100  0.691039   970.9250    0.189470
# 10        10   758.8910  1247.0300  0.858798   441.4040   -0.842665
# 11        11    40.2848  3850.9700 -0.056876  1787.0900    0.046407
# 12        12  1611.8300  1389.6800 -1.432620   144.1850   -0.482640
# ...
